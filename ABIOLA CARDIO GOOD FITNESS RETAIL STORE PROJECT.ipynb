# %% [markdown]
# #                                  Cardio Good Fitness Retail Store Project

# %%
#Importing Libraries for project

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing project data

# %%
path = r"C:\Users\DELL\Downloads\CardioGoodFitness-1.csv"

df = pd.read_csv(path)

# %% [markdown]
# # Calling out data in a dataframe

# %%
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %% [markdown]
# # Overview of data summary

# %%
df.info() 
#Data having 180 entries with zero non-null value
#Data type contains object and ints.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
df.shape
# Out:
# (180, 9)

# %%
#Checking all the feature in the dataframe
df.nunique()
# Out:
# Product           3
# Age              32
# Gender            2
# Education         8
# MaritalStatus     2
# Usage             6
# Fitness           5
# Income           62
# Miles            37
# dtype: int64

# %%
#Checking for missing values and Statistical summary of the data 
df.isna().sum()
#The data shows that there are no missing value.
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
#Checking the descriptive Statistical Summary of the data
df.describe(include="all").T
# Out:
#                count unique        top freq          mean           std  \
# Product          180      3      TM195   80           NaN           NaN
# Age            180.0    NaN        NaN  NaN     28.788889      6.943498
# Gender           180      2       Male  104           NaN           NaN
# Education      180.0    NaN        NaN  NaN     15.572222      1.617055
# MaritalStatus    180      2  Partnered  107           NaN           NaN
# Usage          180.0    NaN        NaN  NaN      3.455556      1.084797
# Fitness        180.0    NaN        NaN  NaN      3.311111      0.958869
# Income         180.0    NaN        NaN  NaN  53719.577778  16506.684226
# Miles          180.0    NaN        NaN  NaN    103.194444     51.863605
#
#                    min       25%      50%      75%       max
# Product            NaN       NaN      NaN      NaN       NaN
# Age               18.0      24.0     26.0     33.0      50.0
# Gender             NaN       NaN      NaN      NaN       NaN
# ...

# %%
#Checking the correlation of the data distribution
df.select_dtypes(include="number").corr()
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %% [markdown]
# #          Customers profile with reference to different products

# %% [markdown]
# # Customers income with the products
#
# * Customer income can be link to the product they use because
#   the average income of the customers is 53,719 according to the
#   data description and 75% of the customers earn above 57,000 anually,
#   which is a reasonable amount to afford even the least amount of treadmill

# %% [markdown]
# #Using a seaburn catplot to visualise the data. Data assigned to the = dataframe, x axis rep the product(categorical data type),y axis rep the income (numerical data type) and kind indicate the kind of plot to draw.

# %%
sns.catplot(data=df, x="Product", y="Income", kind="box",);

# %% [markdown]
# ##The catplot graph above is showing the distribution of customers income and product
# in which people whose income from 55,000 above uses product TM798(GREEN) more than
# the other two product (Blue and Orange).This show that customer with high income rate
# go for product TM798,customers that earn minimum of 50,000 and maximum of 100,000 annully
# are the one using the product TM798(GREEN) While Customer that earn between 30,000 to 68,000 uses
# the other two products simultanously. This indicate that product GREEN has more sophisticated features
# than the other two products.

# %% [markdown]
# # Customers education with the products
#
# *Customer Education refering to the numbers of years a customer have been engaing or aware about the product, which is a major factor that will make a customer to explore more better versions of the products, according to the data description 75% of the total customers have at least 16 years awareness about all the products and through this, a customer will want to go for the best produt.

# %%
#Using seaburn with boxplot to Visualise,
#passing in the argurment,dataframe with both feature representing x and y 

sns.boxplot(df, x='Product', y='Education');

# %% [markdown]
# #Boxplot above basically explain frequent use of the different products over the years by customers. But it was deduced that, the longer the customers uses product TM798 the more they prefer it than the other two products.The minimum years of education a customer who uses product TM798(GREEN) has is 14yrs unlike the other two customers of product BLUE & ORANGE whose minimum education years about the product is 12yrs.

# %% [markdown]
# # Customers usage in respondence  to the different products.
# *Customer Usage of a particular product every week can be deduced from a level of satisfaction they get from using the product on a basis.

# %%
#Using a seaburn with barplot to Visualise 
#passing in the argurment,dataframe with both feature representing x and y and hue to visualise the categories of the product.

# %%
sns.barplot(df, x='Product', y='Usage', hue='Product');

# %% [markdown]
# #Barplot above shows the uasge of each products by the customers and the product with the most frequent usage in a week is product TM798.This explain that product TM798(GREEN) is the only product  that is mostly use more than 3 times in a week.

# %% [markdown]
# #  Miles and fitness of customers with products.
#
# *Miles and Fitness are simultaneously relative, the longer the miles that is been run on a treadmill,the more the fitness a customer gain,through this connected variables, it can be deduced that the more a customer is satisfied with the features of a treadmill (Heartrate monitoring,good motor, easy to use control, etc)  the more miles the customer wants to go on it, which will lead to better fitness level.

# %%
#Using a seaburn with boxplot to Visualise 
#passing in the argurment,dataframe with both feature representing x and y and hue to visualise the categories of the product.

# %%
sns.boxplot(df, x='Fitness', y='Miles',  hue="Product" );

# %% [markdown]
# # Univariate Analyses
#
# # Analyses for target variable, "PRODUCT"

# %%
Product = df["Product"].value_counts() 
#Assign product to dataframe,using value_count() to count the occurrences of each unique value in product 

plt.pie(Product.values, labels=Product.index, autopct='%1.1f%%');
#Using matplotlib with pie chart, passing in the arguments: the values in product, 
#labeling the values, parameter for option to display percentage of values.

#Giving the Variable a Title 
plt.title("Product Distribution");

# %%
#visuliasation of the target variable.

#Purpose is to basically show the description of variable type, which is a categorical variable

#And also  showing the distribution of each product for the  entire customer.

# %% [markdown]
# # Analyses for Customers income

# %%
sns.boxplot(data=df, x="Income");
#Using seaburn with boxplot for Visualisation
#passing in the arguments, data assign to our dataframe, x axix assign to income

# %% [markdown]
# #visuliasation of Income variable.
#
# #Purpose is to basically show the description of variable type, which is a numeric continuous variable.
#
# #And also showing the distribution of income for the  entire customer from min, max income to the large difference of customer income (outliers)

# %% [markdown]
# # Analyses for Customers Education

# %%
#Using seaburn and matplotlib with countplot for Visualisation

#This uses seaburn countplot function to create a bar plot showing the count of each category in the result ploted in variable.
ax = sns.countplot(data=df, x='Education')

#calculate the total numbers of observation in the "Education" column and store it in the variable "total" as floating number.
total = float(len(df['Education']))

#The following loop iterate through each bar in the countplot
for p in ax.patches:

#This calculate the percentage of each category in the count relative to the total number of observations.    
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() / 2.
    y = p.get_height()
    ax.annotate(percentage, (x, y), ha='center', va='center', xytext=(0, 10), textcoords='offset points')

#Using matplotlib function to set the title of the plot to countplot with percentages
plt.title('Countplot with Percentages')

#this display the plot that has been created with seaborn and annotated with percentage
plt.show()

# %%
#visuliasation of Education distribution 
#Purpose is to basically show the description of variable type, which is a numeric discrete variable.
#Showing the numbers of years a Customer has been in aware about a product

# %% [markdown]
# # Analyses for Customers Usage

# %%
#Using seaburn and matplotlib with countplot for Visualisation

#This uses seaburn countplot function to create a bar plot showing the count of each category in the result ploted in variable.
ax = sns.countplot(data=df, x='Usage')

#calculate the total numbers of observation in the "Usage" column and store it in the variable "total" as floating number.
total = float(len(df['Usage']))

#The following loop iterate through each bar in the countplot
for p in ax.patches:

    
#This calculate the percentage of each category in the count relative to the total number of observations.    
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() / 2.
    y = p.get_height()
    ax.annotate(percentage, (x, y), ha='center', va='center', xytext=(0, 10), textcoords='offset points')

#Using matplotlib function to set the title of the plot to countplot with percentages
plt.title('Countplot with Percentages')

#this display the plot that has been created with seaborn and annotated with percentage
plt.show()

# %%
# visuliasation of Usage distribution
#Purpose is to basically show the description of variable type, which is a numeric discrete variable.
#Showing the numbers of days a Customer uses the treadmill in a week

# %% [markdown]
# # Analyses for Customer Fitness

# %%
#Using seaburn and matplotlib with countplot for Visualisation


#This uses seaburn countplot function to create a bar plot showing the count of each category in the result ploted in variable.
ax = sns.countplot(data=df, x='Fitness')

#calculate the total numbers of observation in the "Fitness" column and store it in the variable "total" as floating number.
total = float(len(df['Fitness']))

#The following loop iterate through each bar in the countplot
for p in ax.patches:
    
#This calculate the percentage of each category in the count relative to the total number of observations.    
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() / 2.
    y = p.get_height()
    ax.annotate(percentage, (x, y), ha='center', va='center', xytext=(0, 10), textcoords='offset points')

#Using matplotlib function to set the title of the plot to countplot with percentages
plt.title('Countplot with Percentages')

#this display the plot that has been created with seaborn and annotated with percentage
plt.show()

# %%
# visuliasation of Fitness distribution
#Purpose is to basically show the description of variable type, which is a numeric continuous variable.
#Showing the level of Customer Fitness with a continuous variable.

# %% [markdown]
# # Analyses for Customer Gender

# %%
Gender = df["Gender"].value_counts()
#Assign Gender to dataframe,using value_count() to count the occurrences of each unique value in Gender 

plt.pie(Gender.values, labels=Gender.index, autopct='%1.1f%%');
#Using matplotlib with pie chart, passing in the arguments: the values in Gender, 
#labeling the values, parameter for option to display percentage of values.

plt.title("Gender Distribution"); 
#Giving the Variable a Title

# %%
# visuliasation of Gender distribution
#Purpose is to basically show the description of variable type, which is a Catergorical variable.
#Showing the Gender distribution variable.

# %%
MaritalStatus = df["MaritalStatus"].value_counts()
#Assign MaritalStatus to dataframe,using value_count() to count the occurrences of each unique value in MaritalStatus 

plt.pie(MaritalStatus.values, labels=MaritalStatus.index, autopct='%1.1f%%');
#Using matplotlib with pie chart, passing in the arguments: the values in MaritalStatus, 
#labeling the values, parameter for option to display percentage of values.

plt.title("MaritalStatus");
#Giving the Variable a Title

# %%
# visuliasation of the MaritalStatus distribution
#Purpose is to basically show the description of variable type, which is a Catergorical variable.
#Showing the MaritalStatus distribution variable.

# %% [markdown]
# # Analyses for Customer Gender

# %%
sns.histplot( data=df, x="Age");
#Using seaburn with histplot for Visualisation
#passing in the arguments, data assign to our dataframe, x axis assign to Age

# %%
# visuliasation of the Age distribution
#Purpose is to basically show the description of variable type, which is a Catergorical variable.
#Showing the Age distribution variable.

# %% [markdown]
# #Before going further with our Multivariate analyses, we have to understand relationship within our dataset to give more insight
# on the correlated variable , for image with darker color represent high values and lighter color represent lower values, for instance, usage and fitness colunms on the miles row shows strong postive correlation. This visualisation help in undersstanding the relationship within the data.

# %%
cor_val = df.corr()
#This is Calculate the correlation matrix for the dataframe

df.corr()
#This method computes the correlation of columns in the dataframe

plt.figure(figsize=(10, 5))
#This is a matplotlib function use to create a new figure with a specified size

sns.heatmap(data=cor_val, vmin=-1, annot=True, cmap="Spectral");
#This is a seaburn function to visualise the correlation, 
#data=cor_val : assigning the correlation matrix to a data
#Vmin=-1 : color scale down to -1 for better visualsation of both positive and negative correlation
#annot=True : to show actual correlation values in each cell
#cmap = this is to include color
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2000\2337479632.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor_val = df.corr()
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2000\2337479632.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()

# %% [markdown]
# # Multivariate Analyses

# %% [markdown]
# # Analyses of Fitness,Usage and Product Distribution

# %%
sns.catplot(data=df, x="Fitness", y="Usage", kind="box", hue="Product" );
#Using seaburn with catplot for visualisation
#Passing in augurment, assign dataframe and the passing the axis, box, and hue to product

# %% [markdown]
# # Analyses of Usage, Income and Product Distribution

# %%
sns.catplot(data=df, x="Usage", y="Income", kind="box", hue="Product" );
#Using seaburn with catplot for visualisation
#Passing in augurment, assign dataframe and the passing the axis,box and hue to product

# %% [markdown]
# # Analyses for Gender, Education and Product Distribution

# %%
sns.catplot(data=df, x="Gender", y="Education", kind='box', hue="Product",);
#Using seaburn with catplot for visualisation
#Passing in augurment, assign dataframe and the passing the axis,box and hue to product

# %% [markdown]
# # Analyses for Usage, Age and Product Distribution

# %%
sns.catplot(data=df, x="Usage", y="Age", kind="box", hue="Product" );
#Using seaburn with catplot for visualisation
#Passing in augurment, assign dataframe and the passing the axis,box and hue to product

# %% [markdown]
# # Analyses for Education, Income and Product Distribution

# %%
sns.catplot(data=df, x="Education", y="Income", kind="box", hue="Product" );
#Using seaburn with catplot for visualisation
#Passing in augurment, assign dataframe and the passing the axis and hue to product

# %% [markdown]
# # Key Insights

# %% [markdown]
# *Customers income is one of the major factor that make them wants to go for any of the treadmill
# According to the customer income analyses result shows that people whose income from 55,000 above
# uses product TM798(GREEN) more than the other two treadmill (Blue and Orange).This show that customer with high income rate
# go for product TM798, While Customer that earn between 30,000 to 68,000 uses
# the other two products simultanously. This indicate that product GREEN has more sophisticated features
# than the other two products
#
# *Customer experience/awareness about the treadmill over the years by customers also contribute to the usage of a particular product.
# It was deduced that, the longer a customers uses Treadnill TM798 the more they prefer it than the
# other two Treadmill. The minimum years of experience a customer who uses product TM798(GREEN) has is 14yrs
# unlike the other two customers of product BLUE & ORANGE Traedmill whose minimum education years about the product is 12yrs
# meanwhile 50-70 percent of the customer who uses Treadmil TM798 has 16-18 years about the product respectively,
# which is an action point for a customer to want to go for the most effective treadmill
#
#
# *Customer Usage of a particular product every week can be deduced from a level of satisfaction they get from using the
# treadmill on a particular basis.The uasge of each Treadmill by a customers is relatively with the functionalty of the product
# meanwhile the treadmill with the most frequent usage in a week is product TM798 (GREEN)
# This explain that product TM798(GREEN) is the only product that is mostly use more than 3 times in a week,
# which generate 29% of the total distribution.
#
# *Miles and Fitness are simultaneously relative, the longer the miles that is been run on a treadmill,the more the fitness a customer gain,
# through this connected variables, it can be deduced that the more a customer is satisfied with the features of a treadmill
# (Heartrate monitoring,good motor, easy to use control, etc) the more miles the customer wants to go on it, which will lead to better fitness level.
#
# *The product distribution analyses with the pie chart visualized that treadmill TM798 has the smallest distribution in the chart with 22% of the whole distribution but still have the highest level of usage and miles, which ofcourse result to be the treadmill with the highest level of fitness
#
#
# *Another interesting insight about treadmill 798 is that, even customer that ran 100 miles on the product still get the same
# fitness level as customer that ran above 150 miles on treadmill 498
#
#
# *Gender and marital status does not have any effect on the usage or fitness of the treadmill as both feature have respective
# correspondence on the data.

# %% [markdown]
# # Recommendation

# %% [markdown]
# *The cardio good fitness retail store is advised on the basis of insight generated from the analyses that treadmill 798 should
# have more distribution for the product in the store, since it is the product that customer get the most highest level of fitness from even though, it seems to be more expensive than the other two treadmill because of the level of usage by high income earner.
#
# *The company should do a price review for treadmill 798 for the purpose of those who earn less than 50,000 but would like to use the product.
#
# *The company should engage the manufacturer of the traedmill by requesting that they add similar features
# (Display,good shock absorption etc)on treadmill 798 to the other two product to make customer with less income
# derive similar satisfaction on the other treadmill at a budgeted amount.
#
#
# The company should further engage the manufacturer on the need to add more modern and easy to use, features that will improve the level of usage of the existing customer and that will attract more potential customers
